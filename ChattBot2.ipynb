# %% [markdown]
# <a href="https://colab.research.google.com/github/yudits10/ChattBot/blob/main/ChattBot2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
import string
import random
import nltk
nltk.download('omw-1.4')
import numpy as num
from nltk.stem import WordNetLemmatizer # It has the ability to lemmatize.
import tensorflow as tensorF # A multidimensional array of elements is represented by this symbol.
from tensorflow.keras import Sequential # Sequential groups a linear stack of layers into a tf.keras.Model
from tensorflow.keras.layers import Dense, Dropout

nltk.download("punkt")# required package for tokenization
nltk.download("wordnet")# word database
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
ourData = {"ourIntents": [

             {"tag": "age",
              "patterns": ["how old are you?"],
              "responses": ["I am 2 years old and my birthday was yesterday"]
             },
              {"tag": "greeting",
              "patterns": [ "Hi", "Hello", "Hey"],
              "responses": ["Hi there", "Hello", "Hi :)"],
             },
              {"tag": "goodbye",
              "patterns": [ "bye", "later"],
              "responses": ["Bye", "take care"]
             },
             {"tag": "name",
              "patterns": ["what's your name?", "who are you?"],
              "responses": ["I have no name yet," "You can give me one, and I will appreciate it"]
             }

]}

# %%
lm = WordNetLemmatizer() #for getting words
# lists
ourClasses = []
newWords = []
documentX = []
documentY = []
# Each intent is tokenized into words and the patterns and their associated tags are added to their respective lists.
for intent in ourData["ourIntents"]:
    for pattern in intent["patterns"]:
        ournewTkns = nltk.word_tokenize(pattern)# tokenize the patterns
        newWords.extend(ournewTkns)# extends the tokens
        documentX.append(pattern)
        documentY.append(intent["tag"])


    if intent["tag"] not in ourClasses:# add unexisting tags to their respective classes
        ourClasses.append(intent["tag"])

newWords = [lm.lemmatize(word.lower()) for word in newWords if word not in string.punctuation] # set words to lowercase if not in punctuation
newWords = sorted(set(newWords))# sorting words
ourClasses = sorted(set(ourClasses))# sorting classes

# %%
trainingData = [] # training list array
outEmpty = [0] * len(ourClasses)
# bow model
for idx, doc in enumerate(documentX):
    bagOfwords = []
    text = lm.lemmatize(doc.lower())
    for word in newWords:
        bagOfwords.append(1) if word in text else bagOfwords.append(0)

    outputRow = list(outEmpty)
    outputRow[ourClasses.index(documentY[idx])] = 1
    trainingData.append([bagOfwords, outputRow])

random.shuffle(trainingData)
trainingData = num.array(trainingData, dtype=object)# coverting our data into an array afterv shuffling

x = num.array(list(trainingData[:, 0]))# first trainig phase
y = num.array(list(trainingData[:, 1]))# second training phase

# %%
iShape = (len(x[0]),)
oShape = len(y[0])
# parameter definition
ourNewModel = Sequential()
# In the case of a simple stack of layers, a Sequential model is appropriate

# Dense function adds an output layer
ourNewModel.add(Dense(128, input_shape=iShape, activation="relu"))
# The activation function in a neural network is in charge of converting the node's summed weighted input into activation of the node or output for the input in question
ourNewModel.add(Dropout(0.5))
# Dropout is used to enhance visual perception of input neurons
ourNewModel.add(Dense(64, activation="relu"))
ourNewModel.add(Dropout(0.3))
ourNewModel.add(Dense(oShape, activation = "softmax"))
# below is a callable that returns the value to be used with no arguments
md = tensorF.keras.optimizers.Adam(learning_rate=0.005)
# Below line improves the numerical stability and pushes the computation of the probability distribution into the categorical crossentropy loss function.
ourNewModel.compile(loss='categorical_crossentropy',
              optimizer=md,
              metrics=["accuracy"])
# Output the model in summary
print(ourNewModel.summary())
# Whilst training your Nural Network, you have the option of making the output verbose or simple.
ourNewModel.fit(x, y, epochs=200, verbose=1)
# By epochs, we mean the number of times you repeat a training set.
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1920
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 4)                 260
#
# =================================================================
# Total params: 10436 (40.77 KB)
# Trainable params: 10436 (40.77 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None
# Epoch 1/200
# 1/1 [==============================] - 1s 1s/step - loss: 1.4148 - accuracy: 0.2500
# Epoch 2/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.3619 - accuracy: 0.2500
# Epoch 3/200
# 1/1 [==============================] - 0s 14ms/step - loss: 1.2764 - accuracy: 0.5000
# Epoch 4/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.3031 - accuracy: 0.5000
# Epoch 5/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1991 - accuracy: 0.7500
# Epoch 6/200
# 1/1 [==============================] - 0s 13ms/step - loss: 1.1953 - accuracy: 0.6250
# Epoch 7/200
# 1/1 [==============================] - 0s 15ms/step - loss: 1.1010 - accuracy: 0.7500
# Epoch 8/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.1345 - accuracy: 0.7500
# Epoch 9/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0210 - accuracy: 0.6250
# Epoch 10/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9032 - accuracy: 1.0000
# Epoch 11/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8792 - accuracy: 0.6250
# Epoch 12/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.8349 - accuracy: 0.8750
# Epoch 13/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.7124 - accuracy: 0.8750
# Epoch 14/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.7585 - accuracy: 0.7500
# Epoch 15/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7450 - accuracy: 1.0000
# Epoch 16/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.6444 - accuracy: 1.0000
# Epoch 17/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.6054 - accuracy: 0.7500
# Epoch 18/200
# 1/1 [==============================] - 0s 17ms/step - loss: 0.5501 - accuracy: 0.8750
# Epoch 19/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5838 - accuracy: 0.8750
# Epoch 20/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2991 - accuracy: 1.0000
# Epoch 21/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4965 - accuracy: 0.8750
# Epoch 22/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.3242 - accuracy: 1.0000
# Epoch 23/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2851 - accuracy: 1.0000
# Epoch 24/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2714 - accuracy: 1.0000
# Epoch 25/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.1502 - accuracy: 1.0000
# Epoch 26/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.3264 - accuracy: 1.0000
# Epoch 27/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2530 - accuracy: 1.0000
# Epoch 28/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1138 - accuracy: 1.0000
# Epoch 29/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1741 - accuracy: 1.0000
# Epoch 30/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0805 - accuracy: 1.0000
# Epoch 31/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1641 - accuracy: 1.0000
# Epoch 32/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0527 - accuracy: 1.0000
# Epoch 33/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0532 - accuracy: 1.0000
# Epoch 34/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0473 - accuracy: 1.0000
# Epoch 35/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0570 - accuracy: 1.0000
# Epoch 36/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1066 - accuracy: 1.0000
# Epoch 37/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0576 - accuracy: 1.0000
# Epoch 38/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0564 - accuracy: 1.0000
# Epoch 39/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0670 - accuracy: 1.0000
# Epoch 40/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0321 - accuracy: 1.0000
# Epoch 41/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0561 - accuracy: 1.0000
# Epoch 42/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 43/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 44/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 45/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 46/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 47/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 48/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 49/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 50/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 51/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 52/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 53/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0077 - accuracy: 1.0000
# Epoch 54/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 55/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 56/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 57/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0291 - accuracy: 1.0000
# Epoch 58/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1042 - accuracy: 0.8750
# Epoch 59/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 60/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 61/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 62/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 63/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 64/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 65/200
# 1/1 [==============================] - 0s 14ms/step - loss: 6.9186e-04 - accuracy: 1.0000
# Epoch 66/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 67/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 68/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 69/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0373 - accuracy: 1.0000
# Epoch 70/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 71/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 72/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 73/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.6270e-04 - accuracy: 1.0000
# Epoch 74/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 75/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 76/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 77/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 78/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 79/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 80/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 81/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 82/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 83/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 84/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 85/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0495 - accuracy: 1.0000
# Epoch 86/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 87/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 88/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 89/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0178 - accuracy: 1.0000
# Epoch 90/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 91/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 92/200
# 1/1 [==============================] - 0s 13ms/step - loss: 6.1325e-05 - accuracy: 1.0000
# Epoch 93/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.5752e-04 - accuracy: 1.0000
# Epoch 94/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 95/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 96/200
# 1/1 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 97/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 98/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.9477e-04 - accuracy: 1.0000
# Epoch 99/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 100/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0126 - accuracy: 1.0000
# Epoch 101/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.8217e-04 - accuracy: 1.0000
# Epoch 102/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.1621e-04 - accuracy: 1.0000
# Epoch 103/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.3183e-04 - accuracy: 1.0000
# Epoch 104/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.1591e-04 - accuracy: 1.0000
# Epoch 105/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 106/200
# 1/1 [==============================] - 0s 11ms/step - loss: 3.8387e-04 - accuracy: 1.0000
# Epoch 107/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 108/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 109/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 110/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 111/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0608e-05 - accuracy: 1.0000
# Epoch 112/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 113/200
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5232e-04 - accuracy: 1.0000
# Epoch 114/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.6064e-04 - accuracy: 1.0000
# Epoch 115/200
# 1/1 [==============================] - 0s 11ms/step - loss: 7.7956e-04 - accuracy: 1.0000
# Epoch 116/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 117/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 118/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.3601e-04 - accuracy: 1.0000
# Epoch 119/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 120/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 121/200
# 1/1 [==============================] - 0s 12ms/step - loss: 5.9536e-04 - accuracy: 1.0000
# Epoch 122/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.5811e-04 - accuracy: 1.0000
# Epoch 123/200
# 1/1 [==============================] - 0s 16ms/step - loss: 3.9373e-04 - accuracy: 1.0000
# Epoch 124/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 125/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.6542e-04 - accuracy: 1.0000
# Epoch 126/200
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 127/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.9400e-04 - accuracy: 1.0000
# Epoch 128/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.7437e-04 - accuracy: 1.0000
# Epoch 129/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.9313e-04 - accuracy: 1.0000
# Epoch 130/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 131/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.8463e-04 - accuracy: 1.0000
# Epoch 132/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.3056e-04 - accuracy: 1.0000
# Epoch 133/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0010 - accuracy: 1.0000
# Epoch 134/200
# 1/1 [==============================] - 0s 11ms/step - loss: 7.1083e-04 - accuracy: 1.0000
# Epoch 135/200
# 1/1 [==============================] - 0s 12ms/step - loss: 8.8031e-04 - accuracy: 1.0000
# Epoch 136/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.4553e-04 - accuracy: 1.0000
# Epoch 137/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 138/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0018 - accuracy: 1.0000
# Epoch 139/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 140/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 141/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 142/200
# 1/1 [==============================] - 0s 14ms/step - loss: 4.9555e-04 - accuracy: 1.0000
# Epoch 143/200
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 144/200
# 1/1 [==============================] - 0s 14ms/step - loss: 3.4004e-04 - accuracy: 1.0000
# Epoch 145/200
# 1/1 [==============================] - 0s 13ms/step - loss: 9.3259e-04 - accuracy: 1.0000
# Epoch 146/200
# 1/1 [==============================] - 0s 15ms/step - loss: 8.8854e-04 - accuracy: 1.0000
# Epoch 147/200
# 1/1 [==============================] - 0s 15ms/step - loss: 8.0816e-04 - accuracy: 1.0000
# Epoch 148/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 149/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 150/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.2409e-04 - accuracy: 1.0000
# Epoch 151/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.1502e-04 - accuracy: 1.0000
# Epoch 152/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0016 - accuracy: 1.0000
# Epoch 153/200
# 1/1 [==============================] - 0s 12ms/step - loss: 9.4809e-05 - accuracy: 1.0000
# Epoch 154/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.7498e-04 - accuracy: 1.0000
# Epoch 155/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 156/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.8825e-04 - accuracy: 1.0000
# Epoch 157/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 158/200
# 1/1 [==============================] - 0s 11ms/step - loss: 6.9005e-04 - accuracy: 1.0000
# Epoch 159/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2142e-04 - accuracy: 1.0000
# Epoch 160/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.5006e-04 - accuracy: 1.0000
# Epoch 161/200
# 1/1 [==============================] - 0s 16ms/step - loss: 6.3637e-05 - accuracy: 1.0000
# Epoch 162/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 163/200
# 1/1 [==============================] - 0s 14ms/step - loss: 3.0319e-04 - accuracy: 1.0000
# Epoch 164/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.0372e-04 - accuracy: 1.0000
# Epoch 165/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.7238e-04 - accuracy: 1.0000
# Epoch 166/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7161e-04 - accuracy: 1.0000
# Epoch 167/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.3955e-05 - accuracy: 1.0000
# Epoch 168/200
# 1/1 [==============================] - 0s 16ms/step - loss: 4.5819e-05 - accuracy: 1.0000
# Epoch 169/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 170/200
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 171/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.7247e-04 - accuracy: 1.0000
# Epoch 172/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.2408e-04 - accuracy: 1.0000
# Epoch 173/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0015 - accuracy: 1.0000
# Epoch 174/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.6293e-04 - accuracy: 1.0000
# Epoch 175/200
# 1/1 [==============================] - 0s 12ms/step - loss: 7.8626e-04 - accuracy: 1.0000
# Epoch 176/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.9676e-04 - accuracy: 1.0000
# Epoch 177/200
# 1/1 [==============================] - 0s 11ms/step - loss: 7.7407e-04 - accuracy: 1.0000
# Epoch 178/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.1368e-04 - accuracy: 1.0000
# Epoch 179/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 180/200
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 181/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.7973e-04 - accuracy: 1.0000
# Epoch 182/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.3966e-04 - accuracy: 1.0000
# Epoch 183/200
# 1/1 [==============================] - 0s 13ms/step - loss: 4.7789e-04 - accuracy: 1.0000
# Epoch 184/200
# 1/1 [==============================] - 0s 11ms/step - loss: 8.6986e-05 - accuracy: 1.0000
# Epoch 185/200
# 1/1 [==============================] - 0s 11ms/step - loss: 5.7921e-04 - accuracy: 1.0000
# Epoch 186/200
# 1/1 [==============================] - 0s 12ms/step - loss: 1.0246e-04 - accuracy: 1.0000
# Epoch 187/200
# 1/1 [==============================] - 0s 12ms/step - loss: 4.0205e-04 - accuracy: 1.0000
# Epoch 188/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 189/200
# 1/1 [==============================] - 0s 13ms/step - loss: 3.2581e-04 - accuracy: 1.0000
# Epoch 190/200
# 1/1 [==============================] - 0s 12ms/step - loss: 3.5737e-04 - accuracy: 1.0000
# Epoch 191/200
# 1/1 [==============================] - 0s 12ms/step - loss: 6.7889e-05 - accuracy: 1.0000
# Epoch 192/200
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 193/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.4480e-04 - accuracy: 1.0000
# Epoch 194/200
# 1/1 [==============================] - 0s 12ms/step - loss: 8.5790e-04 - accuracy: 1.0000
# Epoch 195/200
# 1/1 [==============================] - 0s 17ms/step - loss: 3.7998e-04 - accuracy: 1.0000
# Epoch 196/200
# 1/1 [==============================] - 0s 13ms/step - loss: 9.9668e-05 - accuracy: 1.0000
# Epoch 197/200
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 198/200
# 1/1 [==============================] - 0s 11ms/step - loss: 2.8096e-04 - accuracy: 1.0000
# Epoch 199/200
# 1/1 [==============================] - 0s 11ms/step - loss: 1.2458e-04 - accuracy: 1.0000
# Epoch 200/200
# 1/1 [==============================] - 0s 13ms/step - loss: 5.8304e-04 - accuracy: 1.0000
